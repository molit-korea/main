# %% [markdown]
# ## 참여가구 수요분석
# // test폴더 csv데이터 활용

# %%
from IPython.display import display
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

matplotlib.rcParams['axes.unicode_minus'] = False
path = 'c:/Windows/Fonts/malgun.ttf'
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)

# %%
pop40 = pd.read_csv('population_2017_4064.csv', header=None, encoding='euc-kr' )
pop50 = pd.read_csv('population_2017_5064.csv', header=None, encoding='euc-kr' )
fut_40 = pd.read_csv('future_5y_4064.csv', header=None, encoding='euc-kr' )
fut_50 = pd.read_csv('future_5y_5064.csv', header=None, encoding='euc-kr' )

# %%
pop40.head()
# Out:
#             0        1         2         3
# 0  행정구역별(시군구)  가구주의 성별  가구주의 연령별      2017
# 1  행정구역별(시군구)  가구주의 성별  가구주의 연령별  1세대가구-부부
# 2          전국        계    40~44세     96272
# 3          전국        계    45~49세    142668
# 4          전국        계    50~54세    233858

# %%
pop40_=pop40[[0,2,3]]
pop40_
# Out:
#                0         2         3
# 0     행정구역별(시군구)  가구주의 연령별      2017
# 1     행정구역별(시군구)  가구주의 연령별  1세대가구-부부
# 2             전국    40~44세     96272
# 3             전국    45~49세    142668
# 4             전국    50~54세    233858
# 5             전국    55~59세    409535
# 6             전국    60~64세    522850
# 7          서울특별시    40~44세     20820
# 8          서울특별시    45~49세     23071
# 9          서울특별시    50~54세     30026
# 10         서울특별시    55~59세     50426
# 11         서울특별시    60~64세     76642
# 12           종로구    40~44세       326
# 13           종로구    45~49세       451
# 14           종로구    50~54세       548
# 15           종로구    55~59세       862
# 16           종로구    60~64세      1178
# 17            중구    40~44세       341
# 18            중구    45~49세       333
# 19            중구    50~54세       443
# 20            중구    55~59세       735
# 21            중구    60~64세       987
# 22           용산구    40~44세       587
# 23           용산구    45~49세       742
# 24           용산구    50~54세       813
# 25           용산구    55~59세      1159
# 26           용산구    60~64세      1609
# 27           성동구    40~44세       866
# 28           성동구    45~49세       867
# 29           성동구    50~54세       952
# ...          ...       ...       ...
# 1577     제주특별자치도    40~44세      1272
# 1578     제주특별자치도    45~49세      1865
# 1579     제주특별자치도    50~54세      3171
# 1580     제주특별자치도    55~59세      4790
# 1581     제주특별자치도    60~64세      5612
# 1582          읍부    40~44세       305
# 1583          읍부    45~49세       452
# 1584          읍부    50~54세       736
# 1585          읍부    55~59세      1237
# 1586          읍부    60~64세      1422
# 1587          면부    40~44세        60
# 1588          면부    45~49세       105
# 1589          면부    50~54세       186
# 1590          면부    55~59세       322
# 1591          면부    60~64세       383
# 1592          동부    40~44세       907
# 1593          동부    45~49세      1308
# 1594          동부    50~54세      2249
# 1595          동부    55~59세      3231
# 1596          동부    60~64세      3807
# 1597         제주시    40~44세       967
# 1598         제주시    45~49세      1339
# 1599         제주시    50~54세      2253
# 1600         제주시    55~59세      3319
# 1601         제주시    60~64세      3839
# 1602        서귀포시    40~44세       305
# 1603        서귀포시    45~49세       526
# 1604        서귀포시    50~54세       918
# 1605        서귀포시    55~59세      1471
# 1606        서귀포시    60~64세      1773
#
# [1607 rows x 3 columns]

# %%
pop40_ = pop40_[pop40_[0]=='서울특별시']
pop40_
# Out:
#         0       2      3
# 7   서울특별시  40~44세  20820
# 8   서울특별시  45~49세  23071
# 9   서울특별시  50~54세  30026
# 10  서울특별시  55~59세  50426
# 11  서울특별시  60~64세  76642

# %%
plt.bar(pop40_[2],pop40_[3])
# Out:
# <BarContainer object of 5 artists>

# %%
fut_40.head()
# Out:
#            0         1       2       3       4       5       6
# 0  행정구역별(시도)  가구주의 연령별    2020    2021    2022    2023    2024
# 1  행정구역별(시도)  가구주의 연령별      부부      부부      부부      부부      부부
# 2         전국    40~44세   95542   98736  102163  103968  103693
# 3         전국    45~49세  141429  136385  131900  127693  124299
# 4         전국    50~54세  256637  261827  265685  268161  264119

# %%
fut_40_ = fut_40[fut_40[0]=='서울특별시']
fut_40_
# Out:
#         0       1      2      3      4      5      6
# 7   서울특별시  40~44세  20532  21170  21812  22132  22059
# 8   서울특별시  45~49세  23533  22663  21913  21231  20730
# 9   서울특별시  50~54세  35016  36279  37423  38097  37848
# 10  서울특별시  55~59세  53324  51829  51611  50959  52945
# 11  서울특별시  60~64세  88571  92545  93449  94689  93025

# %%
ag_40 = fut_40_[fut_40_[1]=='40~44세']
model1 = ag_40[[2,3,4,5,6]]
ag_40 = fut_40_[fut_40_[1]=='45~49세']
model2 = ag_40[[2,3,4,5,6]]
ag_40 = fut_40_[fut_40_[1]=='50~54세']
model3 = ag_40[[2,3,4,5,6]]
ag_40 = fut_40_[fut_40_[1]=='54~59세']
model4 = ag_40[[2,3,4,5,6]]
ag_40 = fut_40_[fut_40_[1]=='60~64세']
model5 = ag_40[[2,3,4,5,6]]

# %%
# def main():
#     #### 1. bar plot으로 나타낼 데이터 입력
#     models = ['2020', '2021', '2022', '2023', '2024']
#     xticks = fut_40_[1]
#     data = {'2020':model1,
#             '2021':model2,
#             '2022':model3,
#             '2023':model4,
#             '2024':model5}

# ### 2. matplotlib의 figure 및 axis 설정
#     fig, ax = plt.subplots(1,1,figsize=(7,5)) # 1x1 figure matrix 생성, 가로(7인치)x세로(5인치) 크기지정
#     colors = ['salmon', 'orange', 'cadetblue', 'skyblue']
#     width = 0.15

# #### 3. bar 그리기
#     for i, model in enumerate(models):
#         pos = compute_pos(xticks, width, i, models)
#         bar = ax.bar(pos, data[model], width=width*0.95, label=model, color=colors[i])
#         present_height(ax, bar) # bar높이 출력

# #### 4. x축 세부설정
#     ax.set_xticks(range(len(xticks)))
#     ax.set_xticklabels(xticks, fontsize=10)	
#     ax.set_xlabel('Cancer type', fontsize=14)

# #### 5. y축 세부설정
#     ax.set_ylim([0.5,0.76])
#     ax.set_yticks([0.5, 0.55, 0.6, 0.65, 0.7, 0.75])
#     ax.yaxis.set_tick_params(labelsize=10)
#     ax.set_ylabel('Prediction Accuracy', fontsize=14)

# #### 6. 범례 나타내기
#     ax.legend(loc='upper right', shadow=True, ncol=1)

# #### 7. 보조선(눈금선) 나타내기
#     ax.set_axisbelow(True)
#     ax.yaxis.grid(True, color='gray', linestyle='dashed', linewidth=0.5)

# #### 8. 그래프 저장하고 출력하기
#     plt.tight_layout()
#     plt.savefig('ex_barplot.png', format='png', dpi=300)
#     plt.show()
models = ['2020', '2021', '2022', '2023', '2024']
xticks = fut_40_[1]
data = {'2020':model1,
        '2021':model2,
        '2022':model3,
        '2023':model4,
        '2024':model5}

# %%
def compute_pos(xticks, width, i, models):
    index = np.arange(len(xticks))
    n = len(models)
    correction = i-0.5*(n-1)
    return index + width*correction

# %%
def present_height(ax, bar):
    for rect in bar:
        height = rect.get_height()
        posx = rect.get_x()+rect.get_width()*0.5
        posy = height*1.01
        ax.text(posx, posy, '%.3f' % height, rotation=90, ha='center', va='bottom')

# %%
### 2. matplotlib의 figure 및 axis 설정
fig, ax = plt.subplots(1,1,figsize=(10,5)) # 1x1 figure matrix 생성, 가로(7인치)x세로(5인치) 크기지정
colors = ['salmon', 'orange', 'cadetblue', 'skyblue']
width = 0.15

#### 3. bar 그리기
for i, model in enumerate(models):
        pos = compute_pos(xticks, width, i, models)
        bar = ax.bar(pos, data[model], width=width*0.95, label=model, color=colors[i])
        present_height(ax, bar) # bar높이 출력
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-212-2c1300a2dab7> in <module>()
#       7 for i, model in enumerate(models):
#       8         pos = compute_pos(xticks, width, i, models)
# ----> 9         bar = ax.bar(pos, data[model], width=width*0.95, label=model, color=colors[i])
#      10         present_height(ax, bar) # bar높이 출력
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, *args, **kwargs)
#    2205
#    2206         if orientation == 'vertical':
# -> 2207             self._process_unit_info(xdata=x, ydata=height, kwargs=kwargs)
#    2208             if log:
#    2209                 self.set_yscale('log', nonposy='clip')
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _process_unit_info(self, xdata, ydata, kwargs)
#    2142             # we only need to update if there is nothing set yet.
#    2143             if not self.yaxis.have_units():
# -> 2144                 self.yaxis.update_units(ydata)
#    2145
#    2146         # process kwargs 2nd since these will override default units
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1467         neednew = self.converter != converter
#    1468         self.converter = converter
# -> 1469         default = self.converter.default_units(data, self)
#    1470         if default is not None and self.units is None:
#    1471             self.set_units(default)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\category.py in default_units(data, axis)
#     113         # default_units->axis_info->convert
#     114         if axis.units is None:
# --> 115             axis.set_units(UnitData(data))
#     116         else:
#     117             axis.units.update(data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\category.py in __init__(self, data)
#     180         self._counter = itertools.count(start=0)
#     181         if data is not None:
# --> 182             self.update(data)
#     183
#     184     def update(self, data):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\category.py in update(self, data)
#     197         data = np.atleast_1d(np.array(data, dtype=object))
#     198
# --> 199         for val in OrderedDict.fromkeys(data):
#     200             if not isinstance(val, VALID_TYPES):
#     201                 raise TypeError("{val!r} is not a string".format(val=val))
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
#### 4. x축 세부설정
ax.set_xticks(range(len(xticks)))
ax.set_xticklabels(xticks, fontsize=10)
ax.set_xlabel('향후 5년 부부가구', fontsize=14)

#### 5. y축 세부설정
ax.set_ylim([10000,95000])

ax.yaxis.set_tick_params(labelsize=10)
ax.set_ylabel('Prediction Accuracy', fontsize=14)

#### 6. 범례 나타내기
ax.legend(loc='upper right', shadow=True, ncol=1)

#### 7. 보조선(눈금선) 나타내기
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='gray', linestyle='dashed', linewidth=0.5)

#### 8. 그래프 저장하고 출력하기
plt.tight_layout()
plt.savefig('ex_barplot.png', format='png', dpi=300)
plt.show()
